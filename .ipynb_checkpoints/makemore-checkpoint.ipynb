# %%
# Getting the name from the .csv file 
n_list = [first.split(',')[0].split(' ')[0] for first in open('male_names.csv', 'r').read().splitlines()]
name_list = n_list[1:]

# %%
sample = name_list[100:105]
sample
# Out:
# ['rahul', 'abhishekh', 'shelender', 'sanjay', 'ankit']

# %%
b = {}
for w in name_list:
    chs = ['<S>']+list(w)+['<E>']
    for i in range(len(chs)-1):
        biagram = (chs[i]+chs[i+1])
        b[biagram] = b.get(biagram, 0) + 1
# Out:
# {'<S>b': 619, 'ba': 326, 'ar': 1744, 'rj': 95, 'jr': 10, 'ra': 3057, 'aj': 1203, 'j<E>': 626, '<S>r': 1934, 'am': 1538, 'md': 98, 'di': 335, 'in': 888, 'n<E>': 1702, '<S>s': 2624, 'sh': 3457, 'ha': 1888, 'at': 507, 't<E>': 1106, 'bi': 221, 'ir': 474, 're': 460, 'en': 783, 'nd': 1287, 'de': 1377, 'er': 974, 'r<E>': 1559, '<S>a': 1861, 'mi': 368, 'it': 895, '<S>k': 681, 'ku': 254, 'us': 183, 'al': 919, 'l<E>': 1331, 'ka': 792, 'as': 887, 'si': 178, 'id': 148, 'd<E>': 788, 'hi': 963, 'iv': 188, 'v<E>': 346, '<S>v': 813, 'vi': 1054, 'ik': 283, 'kr': 143, 'm<E>': 939, 'sa': 1179, 'an': 3332, 'nj': 307, 'ja': 878, 'ay': 599, 'y<E>': 595, 'ab': 420, 'bh': 501, 'i<E>': 651, 'kh': 205, 'ad': 407, 'da': 282, 'ak': 703, 'k<E>': 570, '<S>g': 427, 'gu': 104, 'ur': 558, 'rm': 143, '<S>c': 232, 'ch': 403, 'rp': 46, 'pa': 855, 'ma': 1168, 'hu': 484, 'rs': 89, 'je': 478, 'ee': 1289, 'ev': 207, '<S>d': 793, 'du': 124, 'rg': 21, 'ge': 79, 'es': 1045, 'h<E>': 1976, '<S>n': 607, 'na': 718, 'ah': 538, 'su
# ...
